# %%
import pandas as pd

df = pd.read_csv("data/raw/data.csv")  # replace with actual filename
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (377937, 11)
# ['Arrival_Date', 'Commodity', 'Commodity_Code', 'District', 'Grade', 'Market', 'Max_Price', 'Min_Price', 'Modal_Price', 'State', 'Variety']
#   Arrival_Date        Commodity  Commodity_Code District Grade   Market  \
# 0   05/02/2015          Cabbage             154    Surat   FAQ  Bardoli
# 1   07/02/2015          Cabbage             154    Surat   FAQ  Bardoli
# 2   26/01/2014          Cabbage             154    Surat   FAQ  Bardoli
# 3   14/02/2014          Cabbage             154    Surat   FAQ  Bardoli
# 4   21/01/2014  Green Avare (W)             165    Surat   FAQ  Bardoli
#
#    Max_Price  Min_Price  Modal_Price    State Variety
# 0     2005.0        0.0       2005.0  Gujarat   Other
# 1     1825.0     1500.0       1825.0  Gujarat   Other
# 2      850.0      500.0        600.0  Gujarat   Other
# 3      400.0      300.0        300.0  Gujarat   Other
# 4     5620.0     4250.0       4250.0  Gujarat   Other

# %%
df.sample(10)
# Out:
#        Arrival_Date                     Commodity  Commodity_Code District  \
# 336083   11/08/2018        Pointed gourd (Parval)             303    Surat
# 141619   10/10/2014           Indian Beans (Seam)             299    Surat
# 282071   24/12/2019        Pointed gourd (Parval)             303    Surat
# 305874   15/05/2019                          Guar              75    Surat
# 64358    28/06/2023  Sesamum(Sesame,Gingelly,Til)              11    Surat
# 196037   21/03/2024                 Ginger(Green)             103    Surat
# 23861    20/04/2007     Green Gram (Moong)(Whole)               9    Surat
# 258681   14/11/2018                      Beetroot             157    Surat
# 236060   27/02/2016                  Green Chilli              87    Surat
# 261384   05/03/2025                 Ginger(Green)             103    Surat
#
#        Grade         Market  Max_Price  Min_Price  Modal_Price    State  \
# 336083   FAQ           Vyra     1750.0     1400.0       1575.0  Gujarat
# 141619   FAQ          Surat     2250.0     1750.0       2000.0  Gujarat
# 282071   FAQ          Surat     4250.0     2250.0       3250.0  Gujarat
# 305874   FAQ  Valod(Buhari)     2250.0     1750.0       1950.0  Gujarat
# 64358    FAQ         Mandvi    14500.0    14500.0      14500.0  Gujarat
# 196037   FAQ          Surat    10300.0     6000.0       8150.0  Gujarat
# 23861    FAQ         Mahuva      675.0      605.0        650.0  Gujarat
# 258681   FAQ          Surat     2500.0     2000.0       2250.0  Gujarat
# 236060   FAQ          Surat     5000.0     4500.0       4750.0  Gujarat
# 261384   FAQ          Surat     3400.0     2000.0       2750.0  Gujarat
#
#        Variety
# 336083   Other
# 141619   Other
# 282071   Other
# 305874   Other
# 64358    Black
# 196037   Other
# 23861    Other
# 258681   Other
# 236060   Other
# 261384   Other

# %%
print(df['Arrival_Date'].nunique(), "unique dates")
print(df['Arrival_Date'].min(), "to", df['Arrival_Date'].max())
# Out:
# 8255 unique dates
# 01/01/2005 to 31/12/2025

# %%
surat_df=df[df['Market'] == 'Surat' ]
print(surat_df.shape)
# Out:
# (153567, 11)

# %%
print(surat_df['Commodity'].nunique(), "unique commodities")
print(surat_df['Commodity'].unique())
print(surat_df['Arrival_Date'].min(), "to", surat_df['Arrival_Date'].max())
# Out:
# 51 unique commodities
# ['Cabbage' 'Capsicum' 'Elephant Yam (Suran)' 'Beetroot' 'Sweet Potato'
#  'Carrot' 'Cucumbar(Kheera)' 'Onion' 'Ridgeguard(Tori)' 'Drumstick'
#  'Potato' 'Mango (Raw-Ripe)' 'Groundnut' 'Ginger(Green)'
#  'Indian Beans (Seam)' 'Yam (Ratalu)' 'French Beans (Frasbean)'
#  'Groundnut pods (raw)' 'Papaya (Raw)' 'Pointed gourd (Parval)'
#  'Cauliflower' 'Lemon' 'Little gourd (Kundru)' 'Kartali (Kantola)'
#  'Peas cod' 'Surat Beans (Papadi)' 'Pegeon Pea (Arhar Fali)'
#  'Rat Tail Radish (Mogari)' 'Brinjal' 'Cowpea(Veg)'
#  'Bhindi(Ladies Finger)' 'Green Chilli' 'Banana - Green' 'Pumpkin'
#  'Tomato' 'Bitter gourd' 'Cluster beans' 'Bottle gourd' 'Garlic'
#  'Turmeric (raw)' 'Sponge gourd' 'Long Melon(Kakri)' 'Round gourd' 'Guar'
#  'Maize' 'Snakeguard' 'Tinda' 'Chilly Capsicum' 'Ginger(Dry)'
#  'Bajra(Pearl Millet/Cumbu)' 'Chapparad Avare']
# 01/01/2005 to 31/12/2024

# %%
commodity_counts = surat_df['Commodity'].value_counts()
print(commodity_counts)
# Out:
# Commodity
# Potato                       5347
# Bhindi(Ladies Finger)        5346
# Tomato                       5337
# Cabbage                      5242
# Onion                        5237
# Cauliflower                  5216
# Brinjal                      5032
# Green Chilli                 4922
# Pointed gourd (Parval)       4731
# Bottle gourd                 4727
# Ginger(Green)                4700
# Surat Beans (Papadi)         4607
# French Beans (Frasbean)      4599
# Little gourd (Kundru)        4551
# Indian Beans (Seam)          4443
# Pegeon Pea (Arhar Fali)      4387
# Lemon                        4310
# Elephant Yam (Suran)         4277
# Carrot                       4229
# Cowpea(Veg)                  4199
# Peas cod                     4145
# Ridgeguard(Tori)             4039
# Bitter gourd                 4024
# Sweet Potato                 3969
# Yam (Ratalu)                 3654
# Drumstick                    3507
# Cucumbar(Kheera)             3346
# Banana - Green               3050
# Pumpkin                      2996
# Mango (Raw-Ripe)             2976
# Papaya (Raw)                 2836
# Beetroot                     2646
# Turmeric (raw)               2522
# Capsicum                     2509
# Cluster beans                2260
# Guar                         2104
# Sponge gourd                 1957
# Kartali (Kantola)            1644
# Groundnut pods (raw)         1506
# Snakeguard                    721
# Rat Tail Radish (Mogari)      544
# Maize                         534
# Garlic                        271
# Groundnut                     200
# Tinda                          90
# Chilly Capsicum                67
# Long Melon(Kakri)               4
# Round gourd                     3
# Ginger(Dry)                     2
# Bajra(Pearl Millet/Cumbu)       1
# Chapparad Avare                 1
# Name: count, dtype: int64

# %%
commodity_counts.head(15)
# Out:
# Commodity
# Potato                     5347
# Bhindi(Ladies Finger)      5346
# Tomato                     5337
# Cabbage                    5242
# Onion                      5237
# Cauliflower                5216
# Brinjal                    5032
# Green Chilli               4922
# Pointed gourd (Parval)     4731
# Bottle gourd               4727
# Ginger(Green)              4700
# Surat Beans (Papadi)       4607
# French Beans (Frasbean)    4599
# Little gourd (Kundru)      4551
# Indian Beans (Seam)        4443
# Name: count, dtype: int64

# %%
for commodity in commodity_counts.head(15).index:
    sub = surat_df[surat_df['Commodity'] == commodity]
    print(commodity, ":", sub['Arrival_Date'].min(), "to", sub['Arrival_Date'].max(), "-", len(sub), "records")
# Out:
# Potato : 01/01/2005 to 31/12/2024 - 5347 records
# Bhindi(Ladies Finger) : 01/01/2005 to 31/12/2024 - 5346 records
# Tomato : 01/01/2005 to 31/12/2024 - 5337 records
# Cabbage : 01/01/2005 to 31/12/2024 - 5242 records
# Onion : 01/01/2005 to 31/12/2024 - 5237 records
# Cauliflower : 01/01/2005 to 31/12/2024 - 5216 records
# Brinjal : 01/01/2005 to 31/12/2024 - 5032 records
# Green Chilli : 01/01/2005 to 31/12/2024 - 4922 records
# Pointed gourd (Parval) : 01/01/2008 to 31/12/2024 - 4731 records
# Bottle gourd : 01/01/2008 to 31/12/2024 - 4727 records
# Ginger(Green) : 01/01/2005 to 31/12/2024 - 4700 records
# Surat Beans (Papadi) : 01/01/2005 to 31/12/2024 - 4607 records
# French Beans (Frasbean) : 01/01/2008 to 31/12/2024 - 4599 records
# Little gourd (Kundru) : 01/01/2008 to 31/12/2024 - 4551 records
# Indian Beans (Seam) : 01/01/2009 to 31/12/2024 - 4443 records

# %%
target_commodities = [
    'Potato', 'Bhindi(Ladies Finger)', 'Tomato', 'Cabbage', 'Onion',
    'Cauliflower', 'Brinjal', 'Green Chilli', 'Pointed gourd (Parval)', 'Bottle gourd'
]

surat_main = surat_df[surat_df['Commodity'].isin(target_commodities)].copy()
print(surat_main.shape)
surat_main['Commodity'].value_counts()
# Out:
# (51137, 11)
# Commodity
# Potato                    5347
# Bhindi(Ladies Finger)     5346
# Tomato                    5337
# Cabbage                   5242
# Onion                     5237
# Cauliflower               5216
# Brinjal                   5032
# Green Chilli              4922
# Pointed gourd (Parval)    4731
# Bottle gourd              4727
# Name: count, dtype: int64

# %%
import os
os.makedirs("data/processed", exist_ok=True)
surat_main.to_csv("data/processed/surat_top10_commodities.csv", index=False)
print("Saved:", surat_main.shape)
# Out:
# Saved: (51137, 11)

# %%
import requests
import pandas as pd

weather_url = "https://archive-api.open-meteo.com/v1/archive"
params = {
    "latitude": 21.17,
    "longitude": 72.83,
    "start_date": "2002-01-01",
    "end_date": "2025-12-31",
    "daily": "precipitation_sum,temperature_2m_max,temperature_2m_min",
    "timezone": "Asia/Kolkata"
}

response = requests.get(weather_url, params=params, timeout=60)
print(response.status_code)
weather_data = response.json()
# Out:
# 200

# %%
weather_df = pd.DataFrame({
    "date": weather_data["daily"]["time"],
    "rainfall_mm": weather_data["daily"]["precipitation_sum"],
    "temp_max": weather_data["daily"]["temperature_2m_max"],
    "temp_min": weather_data["daily"]["temperature_2m_min"]
})

print(weather_df.shape)
weather_df.head()
# Out:
# (8766, 4)
#          date  rainfall_mm  temp_max  temp_min
# 0  2002-01-01          0.0      29.6      19.1
# 1  2002-01-02          0.0      29.5      19.0
# 2  2002-01-03          0.0      28.7      18.5
# 3  2002-01-04          0.0      28.3      17.4
# 4  2002-01-05          0.0      28.0      18.0

# %%
weather_df.to_csv("data/raw/surat_weather_2005_2024.csv", index=False)
print("Saved weather data:", weather_df.shape)
# Out:
# Saved weather data: (8766, 4)

# %%
surat_main['Arrival_Date'] = pd.to_datetime(surat_main['Arrival_Date'], format='%d/%m/%Y')


weather_df['date'] = pd.to_datetime(weather_df['date'])

print(surat_main['Arrival_Date'].dtype, weather_df['date'].dtype)
# Out:
# datetime64[ns] datetime64[ns]

# %%
merged_df = surat_main.merge(weather_df, left_on='Arrival_Date', right_on='date', how='left')
print(merged_df.shape)
merged_df.head()
# Out:
# (51137, 15)
#   Arrival_Date Commodity  Commodity_Code District Grade Market  Max_Price  \
# 0   2015-01-05   Cabbage             154    Surat   FAQ  Surat     1300.0
# 1   2015-01-12   Cabbage             154    Surat   FAQ  Surat     1100.0
# 2   2015-02-05   Cabbage             154    Surat   FAQ  Surat     1200.0
# 3   2015-02-06   Cabbage             154    Surat   FAQ  Surat     1200.0
# 4   2015-02-12   Cabbage             154    Surat   FAQ  Surat     1200.0
#
#    Min_Price  Modal_Price    State Variety       date  rainfall_mm  temp_max  \
# 0      800.0       1050.0  Gujarat   Other 2015-01-05          0.0      27.4
# 1      800.0        950.0  Gujarat   Other 2015-01-12          0.0      28.9
# 2      800.0       1000.0  Gujarat   Other 2015-02-05          0.0      30.4
# 3      800.0       1000.0  Gujarat   Other 2015-02-06          0.0      29.2
# 4      700.0        950.0  Gujarat   Other 2015-02-12          0.0      29.1
#
#    temp_min
# 0      18.3
# 1      16.6
# 2      20.9
# 3      19.9
# 4      19.0

# %%
print(merged_df['rainfall_mm'].isna().sum(), "rows with missing weather data")
# Out:
# 0 rows with missing weather data

# %%
print(surat_main['Arrival_Date'].isna().sum(), "invalid dates in commodity data")
# Out:
# 0 invalid dates in commodity data

# %%
import os
os.makedirs("data/processed", exist_ok=True)
merged_df.to_csv("data/processed/surat_prices_weather_merged.csv", index=False)
print("Saved:", merged_df.shape)
# Out:
# Saved: (51137, 15)

# %%
# !pip install holidays
# Out:
# Requirement already satisfied: holidays in c:\users\rahul tripathi\anaconda3\lib\site-packages (0.100)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in c:\users\rahul tripathi\anaconda3\lib\site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rahul tripathi\anaconda3\lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays) (1.17.0)

# %%
import holidays

india_holidays = holidays.India(years=range(2002, 2026))


festival_df = pd.DataFrame(list(india_holidays.items()), columns=['date', 'festival_name'])
festival_df['date'] = pd.to_datetime(festival_df['date'])
festival_df = festival_df.sort_values('date').reset_index(drop=True)

print(festival_df.shape)
festival_df.head(15)
# Out:
# (430, 2)
#          date                 festival_name
# 0  2002-01-26                  Republic Day
# 1  2002-02-23           Id-ul-Zuha (Bakrid)
# 2  2002-03-12               Maha Shivaratri
# 3  2002-03-25                      Muharram
# 4  2002-03-29                   Good Friday
# 5  2002-04-14  Dr. B. R. Ambedkar's Jayanti
# 6  2002-04-25               Mahavir Jayanti
# 7  2002-05-19                Buddha Purnima
# 8  2002-05-25                 Milad-un-Nabi
# 9  2002-08-15              Independence Day
# 10 2002-08-31       Janmashtami (Vaishnava)
# 11 2002-10-02      Mahatma Gandhi's Jayanti
# 12 2002-10-14         Dussehra (Mahanavami)
# 13 2002-10-15                      Dussehra
# 14 2002-11-04            Diwali (Deepavali)

# %%
major_festivals = ['Diwali (Deepavali)', 'Holi', 'Dussehra']

major_festival_df = festival_df[festival_df['festival_name'].isin(major_festivals)].reset_index(drop=True)
print(major_festival_df.shape)
major_festival_df
# Out:
# (68, 2)
#          date       festival_name
# 0  2002-10-15            Dussehra
# 1  2002-11-04  Diwali (Deepavali)
# 2  2003-03-18                Holi
# 3  2003-10-05            Dussehra
# 4  2003-10-25  Diwali (Deepavali)
# ..        ...                 ...
# 63 2024-03-25                Holi
# 64 2024-10-12            Dussehra
# 65 2024-10-31  Diwali (Deepavali)
# 66 2025-03-14                Holi
# 67 2025-10-20  Diwali (Deepavali)
#
# [68 rows x 2 columns]

# %%
festival_dates = major_festival_df['date'].values

merged_df['days_to_nearest_festival'] = merged_df['Arrival_Date'].apply(
    lambda d: min(abs((d - pd.Timestamp(fd)).days) for fd in festival_dates)
)

merged_df['is_festival_week'] = merged_df['days_to_nearest_festival'] <= 7

print(merged_df['is_festival_week'].sum(), "rows flagged as festival week")
print(merged_df['is_festival_week'].mean() * 100, "% of rows")
# Out:
# 5628 rows flagged as festival week
# 11.005729706474764 % of rows

# %%
merged_df.to_csv("data/processed/surat_final_dataset.csv", index=False)
print("Saved:", merged_df.shape)
print(merged_df.columns.tolist())
# Out:
# Saved: (51137, 17)
# ['Arrival_Date', 'Commodity', 'Commodity_Code', 'District', 'Grade', 'Market', 'Max_Price', 'Min_Price', 'Modal_Price', 'State', 'Variety', 'date', 'rainfall_mm', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week']

# %%
for col in ['State', 'District', 'Market', 'Grade', 'Commodity_Code']:
    print(col, ":", merged_df[col].nunique(), "unique values ->", merged_df[col].unique()[:5])
# Out:
# State : 1 unique values -> ['Gujarat']
# District : 1 unique values -> ['Surat']
# Market : 1 unique values -> ['Surat']
# Grade : 1 unique values -> ['FAQ']
# Commodity_Code : 10 unique values -> [154  23  24 303  34]

# %%
merged_df = merged_df.drop(columns=['State', 'District', 'Market', 'Grade', 'Commodity_Code', 'date'])
print(merged_df.shape)
merged_df.columns.tolist()
# Out:
# (51137, 11)
# ['Arrival_Date',
#  'Commodity',
#  'Max_Price',
#  'Min_Price',
#  'Modal_Price',
#  'Variety',
#  'rainfall_mm',
#  'temp_max',
#  'temp_min',
#  'days_to_nearest_festival',
#  'is_festival_week']

# %%
merged_df.sample(10)
# Out:
#       Arrival_Date               Commodity  Max_Price  Min_Price  Modal_Price  \
# 23154   2011-06-11             Cauliflower     1000.0      700.0        850.0
# 39895   2018-11-18                 Cabbage     1300.0      300.0        800.0
# 10088   2025-06-20            Green Chilli     6000.0     3000.0       4500.0
# 25904   2006-08-31             Cauliflower     1500.0     1000.0       1250.0
# 25253   2004-09-08             Cauliflower      800.0      400.0        600.0
# 28271   2024-03-22                   Onion     1900.0      600.0       1250.0
# 29800   2025-03-09                 Cabbage     1000.0      500.0        750.0
# 17633   2021-02-15                   Onion     4250.0     2250.0       3250.0
# 36972   2011-11-25                 Cabbage      750.0      500.0        625.0
# 39001   2022-05-18  Pointed gourd (Parval)     4650.0     3500.0       4075.0
#
#       Variety  rainfall_mm  temp_max  temp_min  days_to_nearest_festival  \
# 23154   Other          0.0      33.4      27.8                       117
# 39895   Other          0.0      35.2      20.1                        11
# 10088   Other          2.3      31.8      26.5                        98
# 25904   Other          0.2      28.2      25.2                        51
# 25253   Other          0.1      31.1      26.9                        44
# 28271   Other          0.0      37.1      20.6                         3
# 29800   Other          0.0      38.1      21.5                         5
# 17633   Other          0.0      32.4      18.5                        42
# 36972   Other          0.0      32.0      21.7                        30
# 39001   Other          0.0      34.5      27.3                        61
#
#        is_festival_week
# 23154             False
# 39895             False
# 10088             False
# 25904             False
# 25253             False
# 28271              True
# 29800              True
# 17633             False
# 36972             False
# 39001             False

# %%
print(merged_df.groupby('Commodity')['Variety'].unique())
# Out:
# Commodity
# Bhindi(Ladies Finger)            [Other, Bhindi]
# Bottle gourd               [Other, Bottle Gourd]
# Brinjal                         [Other, Brinjal]
# Cabbage                         [Other, Cabbage]
# Cauliflower                 [Other, Cauliflower]
# Green Chilli               [Other, Green Chilly]
# Onion                             [Other, Nasik]
# Pointed gourd (Parval)                   [Other]
# Potato                    [Other, Kufri Giriraj]
# Tomato                           [Other, Tomato]
# Name: Variety, dtype: object

# %%
merged_df = merged_df.drop(columns=['Variety'])
print(merged_df.shape)
merged_df.columns.tolist()
# Out:
# (51137, 10)
# ['Arrival_Date',
#  'Commodity',
#  'Max_Price',
#  'Min_Price',
#  'Modal_Price',
#  'rainfall_mm',
#  'temp_max',
#  'temp_min',
#  'days_to_nearest_festival',
#  'is_festival_week']

# %%
merged_df.to_csv("data/processed/surat_final_dataset.csv", index=False)
print("Saved:", merged_df.shape)
# Out:
# Saved: (51137, 10)

# %%
print(merged_df.columns.tolist())
# Out:
# ['Arrival_Date', 'Commodity', 'Max_Price', 'Min_Price', 'Modal_Price', 'rainfall_mm', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week']

# %%
merged_df.to_csv("data/processed/surat_final_dataset.csv", index=False)
print("Saved:", merged_df.shape)
# Out:
# Saved: (51137, 10)

# %%
check_df = pd.read_csv("data/processed/surat_final_dataset.csv")
print(check_df.shape)
print(check_df.columns.tolist())
# Out:
# (51137, 10)
# ['Arrival_Date', 'Commodity', 'Max_Price', 'Min_Price', 'Modal_Price', 'rainfall_mm', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/processed/surat_final_dataset.csv")
df['Arrival_Date'] = pd.to_datetime(df['Arrival_Date'])
df = df.sort_values('Arrival_Date')

print(df.shape)
df.describe()
# Out:
# (51137, 10)
#                         Arrival_Date     Max_Price     Min_Price  \
# count                          51137  51137.000000  51137.000000
# mean   2015-11-23 16:50:20.404012800   2263.955746   1165.502611
# min              2002-04-01 00:00:00     50.000000     30.000000
# 25%              2010-11-26 00:00:00   1100.000000    500.000000
# 50%              2016-08-13 00:00:00   1800.000000    900.000000
# 75%              2021-01-29 00:00:00   3000.000000   1500.000000
# max              2025-11-05 00:00:00  25000.000000  22500.000000
# std                              NaN   1652.674846   1006.398082
#
#         Modal_Price   rainfall_mm      temp_max      temp_min  \
# count  51137.000000  51137.000000  51137.000000  51137.000000
# mean    1714.533660      3.522013     31.890097     23.368723
# min       45.000000      0.000000     19.800000     11.600000
# 25%      825.000000      0.000000     29.300000     20.600000
# 50%     1350.000000      0.000000     31.400000     24.800000
# 75%     2250.000000      1.600000     34.000000     26.100000
# max    23750.000000    326.000000     44.500000     30.000000
# std     1282.070363     11.961390      3.420285      3.769032
#
#        days_to_nearest_festival
# count              51137.000000
# mean                  46.567612
# min                    0.000000
# 25%                   20.000000
# 50%                   43.000000
# 75%                   67.000000
# max                  197.000000
# std                   32.036628

# %%
df.groupby('Commodity')['Modal_Price'].describe()
# Out:
#                          count         mean          std    min       25%  \
# Commodity
# Bhindi(Ladies Finger)   5346.0  2087.119342  1064.592487  100.0  1250.000
# Bottle gourd            4727.0  1464.792151   928.812344   60.0   825.000
# Brinjal                 5032.0  1915.815282  1245.523421  175.0  1000.000
# Cabbage                 5242.0   863.306276   506.021178   45.0   475.000
# Cauliflower             5216.0  1519.099022   766.533606   60.0   950.000
# Green Chilli            4922.0  2546.933056  1307.491701  275.0  1565.625
# Onion                   5237.0  1299.843660   936.767873   45.0   650.000
# Pointed gourd (Parval)  4731.0  3371.816318  1812.830901  200.0  2075.000
# Potato                  5347.0  1009.059660   499.030708  105.0   600.000
# Tomato                  5337.0  1276.756605  1024.078450   95.0   600.000
#
#                            50%     75%      max
# Commodity
# Bhindi(Ladies Finger)   1887.5  2625.0   7250.0
# Bottle gourd            1200.0  1787.5   7000.0
# Brinjal                 1550.0  2500.0   7750.0
# Cabbage                  700.0  1150.0   3500.0
# Cauliflower             1375.0  1975.0   7500.0
# Green Chilli            2250.0  3250.0   9000.0
# Onion                   1050.0  1600.0   6125.0
# Pointed gourd (Parval)  3125.0  4500.0  23750.0
# Potato                   950.0  1300.0   3875.0
# Tomato                   950.0  1550.0  10000.0

# %%
onion = df[df['Commodity'] == 'Onion']

plt.figure(figsize=(14, 5))
plt.plot(onion['Arrival_Date'], onion['Modal_Price'])
plt.title('Onion Modal Price Over Time - Surat APMC')
plt.xlabel('Date')
plt.ylabel('Price ')
plt.show()

# %%
extreme_tomato = df[(df['Commodity'] == 'Tomato')].nlargest(10, 'Modal_Price')
print(extreme_tomato[['Arrival_Date', 'Min_Price', 'Max_Price', 'Modal_Price']])

extreme_parval = df[(df['Commodity'] == 'Pointed gourd (Parval)')].nlargest(10, 'Modal_Price')
print(extreme_parval[['Arrival_Date', 'Min_Price', 'Max_Price', 'Modal_Price']])
# Out:
#       Arrival_Date  Min_Price  Max_Price  Modal_Price
# 18468   2023-07-31     6000.0    14000.0      10000.0
# 18467   2023-07-28     6000.0    13000.0       9500.0
# 39520   2023-07-19     6000.0    12000.0       9000.0
# 51100   2023-07-20     6000.0    11500.0       8750.0
# 9010    2023-07-24     5000.0    12500.0       8750.0
# 39521   2023-07-26     5000.0    12000.0       8500.0
# 9011    2023-07-27     5000.0    12000.0       8500.0
# 18463   2023-07-06     5000.0    11500.0       8250.0
# 51097   2023-07-10     5000.0    11000.0       8000.0
# 39518   2023-07-11     5000.0    11000.0       8000.0
#       Arrival_Date  Min_Price  Max_Price  Modal_Price
# 1658    2004-08-19    22500.0    25000.0      23750.0
# 1659    2004-11-10    20000.0    22500.0      21250.0
# 25195   2004-11-06    20000.0    21000.0      20500.0
# 45174   2004-10-15    19000.0    20000.0      19500.0
# 23916   2005-10-10    19000.0    20000.0      19500.0
# 45622   2003-04-19    15000.0    16000.0      15500.0
# 49402   2006-05-19    12500.0    13500.0      13000.0
# 1012    2006-05-17    11500.0    14000.0      12750.0
# 8337    2024-09-12     7500.0    17500.0      12500.0
# 1013    2006-05-18    12000.0    12500.0      12250.0

# %%
df['month'] = df['Arrival_Date'].dt.month

plt.figure(figsize=(14, 6))
sns.boxplot(data=df[df['Commodity'] == 'Onion'], x='month', y='Modal_Price')
plt.title('Onion Price by Month - Surat APMC (2002-2025)')
plt.xlabel('Month')
plt.ylabel('Modal Price (Rs/Quintal)')
plt.show()

# %%
for commodity in ['Onion', 'Tomato', 'Potato']:
    print(f"\n--- {commodity} ---")
    print(df[df['Commodity'] == commodity].groupby('month')['Modal_Price'].mean().round(0))
# Out:
# --- Onion ---
# month
# 1     1504.0
# 2     1234.0
# 3      933.0
# 4      722.0
# 5      806.0
# 6      926.0
# 7     1130.0
# 8     1471.0
# 9     1463.0
# 10    1961.0
# 11    2087.0
# 12    1670.0
# Name: Modal_Price, dtype: float64
#
# --- Tomato ---
# month
# 1      885.0
# 2      793.0
# 3      728.0
# 4      775.0
# 5      972.0
# 6     1641.0
# 7     2337.0
# 8     1627.0
# 9     1165.0
# 10    1599.0
# 11    1484.0
# 12    1199.0
# Name: Modal_Price, dtype: float64
#
# --- Potato ---
# month
# 1      942.0
# 2      717.0
# 3      768.0
# 4      937.0
# 5     1007.0
# 6     1003.0
# 7     1042.0
# 8     1102.0
# 9     1046.0
# 10    1245.0
# 11    1242.0
# 12    1112.0
# Name: Modal_Price, dtype: float64

# %%
for commodity in ['Onion', 'Tomato', 'Potato']:
    corr = df[df['Commodity'] == commodity][['Modal_Price', 'rainfall_mm']].corr().iloc[0,1]
    print(commodity, "price-rainfall correlation:", round(corr, 3))
# Out:
# Onion price-rainfall correlation: 0.018
# Tomato price-rainfall correlation: 0.201
# Potato price-rainfall correlation: 0.035

# %%
for commodity in ['Onion', 'Tomato', 'Potato']:
    sub = df[df['Commodity'] == commodity]
    festival_avg = sub[sub['is_festival_week']]['Modal_Price'].mean()
    normal_avg = sub[~sub['is_festival_week']]['Modal_Price'].mean()
    print(f"{commodity}: festival week avg = {round(festival_avg)}, normal avg = {round(normal_avg)}")
# Out:
# Onion: festival week avg = 1656, normal avg = 1256
# Tomato: festival week avg = 1269, normal avg = 1278
# Potato: festival week avg = 1068, normal avg = 1002

# %%
df = df.sort_values('Arrival_Date')
df['rainfall_7day_sum'] = df.groupby('Commodity')['rainfall_mm'].transform(lambda x: x.rolling(7, min_periods=1).sum())

tomato_corr = df[df['Commodity'] == 'Tomato'][['Modal_Price', 'rainfall_7day_sum']].corr().iloc[0,1]
print("Tomato price vs 7-day rainfall correlation:", round(tomato_corr, 3))
# Out:
# Tomato price vs 7-day rainfall correlation: 0.327

# %%
df.to_csv("data/processed/surat_final_dataset.csv", index=False)
print("Saved:", df.shape)
# Out:
# Saved: (51137, 12)

# %%
df['year'] = df['Arrival_Date'].dt.year
df['month'] = df['Arrival_Date'].dt.month
df['day_of_week'] = df['Arrival_Date'].dt.dayofweek
df['week_of_year'] = df['Arrival_Date'].dt.isocalendar().week

print(df[['Arrival_Date', 'year', 'month', 'day_of_week', 'week_of_year']].head())
# Out:
#       Arrival_Date  year  month  day_of_week  week_of_year
# 5479    2002-04-01  2002      4            0            14
# 31456   2002-04-04  2002      4            3            14
# 23773   2002-04-09  2002      4            1            15
# 31457   2002-04-09  2002      4            1            15
# 5474    2002-08-26  2002      8            0            35

# %%
dup_check = df.groupby(['Commodity', 'Arrival_Date']).size().reset_index(name='count')
dup_check[dup_check['count'] > 1].sort_values('count', ascending=False).head(10)
# Out:
#                    Commodity Arrival_Date  count
# 496    Bhindi(Ladies Finger)   2006-03-10      2
# 20837            Cauliflower   2006-03-10      2
# 25847           Green Chilli   2006-03-10      2
# 40959                 Potato   2006-03-10      2
# 46302                 Tomato   2006-03-10      2

# %%
df_dedup = df.groupby(['Commodity', 'Arrival_Date'], as_index=False).agg({
    'Modal_Price': 'mean',
    'Min_Price': 'mean',
    'Max_Price': 'mean',
    'rainfall_mm': 'first',
    'rainfall_7day_sum': 'first',
    'temp_max': 'first',
    'temp_min': 'first',
    'days_to_nearest_festival': 'first',
    'is_festival_week': 'first'
})

print(df.shape, "->", df_dedup.shape)
# Out:
# (51137, 15) -> (51132, 11)

# %%
def add_calendar_aware_lags(group):
    group = group.set_index('Arrival_Date').sort_index()
    full_range = pd.date_range(group.index.min(), group.index.max(), freq='D')
    group = group.reindex(full_range)
    
    for lag in [1, 7, 14, 30]:
        group[f'price_lag_{lag}'] = group['Modal_Price'].shift(lag)
    
    return group

# %%
lagged = df_dedup.groupby('Commodity', group_keys=True).apply(add_calendar_aware_lags, include_groups=False)
lagged = lagged.reset_index().rename(columns={'level_1': 'Arrival_Date'})
lagged = lagged.dropna(subset=['Modal_Price'])

print(lagged.shape)
lagged[['Commodity', 'Arrival_Date', 'Modal_Price', 'price_lag_1', 'price_lag_7', 'price_lag_14', 'price_lag_30']].head(10)
# Out:
# (51132, 15)
#                  Commodity Arrival_Date  Modal_Price  price_lag_1  \
# 0    Bhindi(Ladies Finger)   2002-08-26        135.0          NaN
# 9    Bhindi(Ladies Finger)   2002-09-04        100.0          NaN
# 11   Bhindi(Ladies Finger)   2002-09-06       1000.0          NaN
# 12   Bhindi(Ladies Finger)   2002-09-07       1050.0       1000.0
# 136  Bhindi(Ladies Finger)   2003-01-09       1100.0          NaN
# 137  Bhindi(Ladies Finger)   2003-01-10       1125.0       1100.0
# 140  Bhindi(Ladies Finger)   2003-01-13       1100.0          NaN
# 142  Bhindi(Ladies Finger)   2003-01-15        900.0          NaN
# 143  Bhindi(Ladies Finger)   2003-01-16       1000.0        900.0
# 144  Bhindi(Ladies Finger)   2003-01-17       1075.0       1000.0
#
#      price_lag_7  price_lag_14  price_lag_30
# 0            NaN           NaN           NaN
# 9            NaN           NaN           NaN
# 11           NaN           NaN           NaN
# 12           NaN           NaN           NaN
# 136          NaN           NaN           NaN
# 137          NaN           NaN           NaN
# 140          NaN           NaN           NaN
# 142          NaN           NaN           NaN
# 143       1100.0           NaN           NaN
# 144       1125.0           NaN           NaN

# %%
print(df.columns.tolist())
# Out:
# ['Arrival_Date', 'Commodity', 'Max_Price', 'Min_Price', 'Modal_Price', 'rainfall_mm', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week', 'month', 'rainfall_7day_sum', 'year', 'day_of_week', 'week_of_year']

# %%
old_lag_cols = ['price_lag_1', 'price_lag_7', 'price_lag_14', 'price_lag_30']
df = df.drop(columns=[c for c in old_lag_cols if c in df.columns])

print(df.columns.tolist())
# Out:
# ['Arrival_Date', 'Commodity', 'Max_Price', 'Min_Price', 'Modal_Price', 'rainfall_mm', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week', 'month', 'rainfall_7day_sum', 'year', 'day_of_week', 'week_of_year']

# %%
# Drop old flawed row-based lag columns and old row-based rolling columns
cols_to_drop = [
    'price_lag_1_x', 'price_lag_7_x', 'price_lag_14_x', 'price_lag_30_x',
    'price_rolling_mean_7', 'price_rolling_std_7',
    'price_rolling_mean_30', 'price_rolling_std_30',
    'days_since_last_report'
]
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns])

# Rename the correct (_y) lag columns back to clean names
df = df.rename(columns={
    'price_lag_1_y': 'price_lag_1',
    'price_lag_7_y': 'price_lag_7',
    'price_lag_14_y': 'price_lag_14',
    'price_lag_30_y': 'price_lag_30'
})

print(df.shape)
print(df.columns.tolist())
# Out:
# (51137, 15)
# ['Arrival_Date', 'Commodity', 'Max_Price', 'Min_Price', 'Modal_Price', 'rainfall_mm', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week', 'month', 'rainfall_7day_sum', 'year', 'day_of_week', 'week_of_year']

# %%
df.to_csv("data/processed/surat_features_full.csv", index=False)
print("Saved:", df.shape)
# Out:
# Saved: (51137, 15)

# %%
model_df = pd.read_csv("data/processed/surat_model_ready.csv")
model_df['Arrival_Date'] = pd.to_datetime(model_df['Arrival_Date'])

print(model_df.shape)
print(model_df.columns.tolist())
print(model_df.isna().sum())
# Out:
# (51137, 23)
# ['Commodity', 'Arrival_Date', 'Modal_Price', 'Min_Price', 'Max_Price', 'rainfall_mm', 'rainfall_7day_sum', 'temp_max', 'temp_min', 'days_to_nearest_festival', 'is_festival_week', 'year', 'month', 'day_of_week', 'week_of_year', 'price_lag_1', 'price_lag_7', 'price_lag_14', 'price_lag_30', 'price_rolling_mean_7D', 'price_rolling_std_7D', 'price_rolling_mean_30D', 'price_rolling_std_30D']
# Commodity                       0
# Arrival_Date                    0
# Modal_Price                     0
# Min_Price                       0
# Max_Price                       0
# rainfall_mm                     0
# rainfall_7day_sum               0
# temp_max                        0
# temp_min                        0
# days_to_nearest_festival        0
# is_festival_week                0
# year                            0
# month                           0
# day_of_week                     0
# week_of_year                    0
# price_lag_1                 12583
# price_lag_7                 11256
# price_lag_14                11804
# price_lag_30                17244
# price_rolling_mean_7D          10
# price_rolling_std_7D          787
# price_rolling_mean_30D         10
# price_rolling_std_30D          76
# dtype: int64

# %%
model_df.to_csv("data/processed/surat_model_ready.csv", index=False)
print("Saved:", model_df.shape)

# %%
from sklearn.preprocessing import OneHotEncoder

model_df = model_df.sort_values('Arrival_Date').reset_index(drop=True)

encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
commodity_encoded = encoder.fit_transform(model_df[['Commodity']])

# Turn the encoded array into a DataFrame with proper column names
encoded_cols = encoder.get_feature_names_out(['Commodity'])
commodity_df = pd.DataFrame(commodity_encoded, columns=encoded_cols, index=model_df.index)

# Combine back with the rest of the data
model_df = pd.concat([model_df.drop(columns=['Commodity']), commodity_df], axis=1)

print(model_df.shape)
model_df.columns.tolist()
# Out:
# (51137, 32)
# ['Arrival_Date',
#  'Modal_Price',
#  'Min_Price',
#  'Max_Price',
#  'rainfall_mm',
#  'rainfall_7day_sum',
#  'temp_max',
#  'temp_min',
#  'days_to_nearest_festival',
#  'is_festival_week',
#  'year',
#  'month',
#  'day_of_week',
#  'week_of_year',
#  'price_lag_1',
#  'price_lag_7',
#  'price_lag_14',
#  'price_lag_30',
#  'price_rolling_mean_7D',
#  'price_rolling_std_7D',
#  'price_rolling_mean_30D',
#  'price_rolling_std_30D',
#  'Commodity_Bhindi(Ladies Finger)',
#  'Commodity_Bottle gourd',
#  'Commodity_Brinjal',
#  'Commodity_Cabbage',
#  'Commodity_Cauliflower',
#  'Commodity_Green Chilli',
#  'Commodity_Onion',
#  'Commodity_Pointed gourd (Parval)',
#  'Commodity_Potato',
#  'Commodity_Tomato']

# %%
train_df = model_df[model_df['Arrival_Date'] < '2024-01-01']
test_df = model_df[model_df['Arrival_Date'] >= '2024-01-01']

print("Train:", train_df.shape, "| Date range:", train_df['Arrival_Date'].min(), "to", train_df['Arrival_Date'].max())
print("Test:", test_df.shape, "| Date range:", test_df['Arrival_Date'].min(), "to", test_df['Arrival_Date'].max())
# Out:
# Train: (45849, 32) | Date range: 2002-04-01 00:00:00 to 2023-12-30 00:00:00
# Test: (5288, 32) | Date range: 2024-01-02 00:00:00 to 2025-11-05 00:00:00

# %%
drop_cols = ['Arrival_Date', 'Modal_Price', 'Min_Price', 'Max_Price']  # Modal_Price is our target, Arrival_Date isn't a usable numeric feature directly

X_train = train_df.drop(columns=drop_cols)
y_train = train_df['Modal_Price']

X_test = test_df.drop(columns=drop_cols)
y_test = test_df['Modal_Price']

print(X_train.shape, X_test.shape)
# Out:
# (45849, 28) (5288, 28)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\rahul tripathi\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: numpy in c:\users\rahul tripathi\anaconda3\lib\site-packages (from xgboost) (2.3.5)
# Requirement already satisfied: scipy in c:\users\rahul tripathi\anaconda3\lib\site-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error , r2_score
import numpy as np

model = XGBRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.05,
    random_state=42
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mape = mean_absolute_percentage_error(y_test, y_pred)
r2 =  r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"MAPE: {mape:.2%}")
print(f"r2 :{r2}")
# Out:
# MAE: 248.40
# RMSE: 440.96
# MAPE: 8.57%
# r2 :0.9051461465346

# %%
results_df = test_df[['Commodity_' + c if 'Commodity_' + c in test_df.columns else c for c in []]].copy()  # placeholder, fixed below

# Simpler approach: rebuild a comparison dataframe using the original test_df before one-hot encoding
comparison = pd.DataFrame({
    'Arrival_Date': test_df['Arrival_Date'].values,
    'actual': y_test.values,
    'predicted': y_pred
})

# Recover which commodity each row belongs to from the one-hot columns
commodity_cols = [c for c in test_df.columns if c.startswith('Commodity_')]
comparison['Commodity'] = test_df[commodity_cols].idxmax(axis=1).str.replace('Commodity_', '')

comparison['abs_error'] = abs(comparison['actual'] - comparison['predicted'])
comparison['pct_error'] = comparison['abs_error'] / comparison['actual']

per_commodity = comparison.groupby('Commodity').agg(
    mae=('abs_error', 'mean'),
    mape=('pct_error', 'mean')
).sort_values('mape', ascending=False)

print(per_commodity)
# Out:
# Empty DataFrame
# Columns: [mae, mape]
# Index: []
